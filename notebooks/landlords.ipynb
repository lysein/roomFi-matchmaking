# %%
# config.ipynb cell
import os
import sys
import supabase

# Dynamically add the parent directory to the Python path
current_dir = os.path.dirname(os.path.abspath(__name__))
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)

import uuid
import random
import json
from faker import Faker
from datetime import datetime
from supabase import create_client, Client
from src.api.config import settings

# Supabase credentials
SUPABASE_URL = settings.SUPABASE_URL
SUPABASE_KEY = settings.SUPABASE_ANON_KEY
client = create_client(SUPABASE_URL, SUPABASE_KEY)

# %% [markdown]
# ✅ Step 2: Get Distinct owner_user_ids from properties

# %%
response = client.table("properties").select("owner_user_id").execute()
owner_ids = list({item["owner_user_id"] for item in response.data})
print(f"{len(owner_ids)} unique owner_user_ids found.")
# Out:
# 642 unique owner_user_ids found.

# %% [markdown]
# ✅ Step 3: Get Existing Landlord Profiles

# %%
existing = client.table("landlord_profile").select("user_id").in_("user_id", owner_ids).execute()
existing_user_ids = {item["user_id"] for item in existing.data}

# Filter only new ones
new_owner_ids = [uid for uid in owner_ids if uid not in existing_user_ids]
print(f"{len(new_owner_ids)} new landlord profiles to create.")
# Out:
# 642 new landlord profiles to create.

# %% [markdown]
# 🧪 Step-by-Step Jupyter Implementation (Supabase Client)
#
# ✅ Step 1: Fetch all properties and group by owner_user_id

# %%
from collections import defaultdict
from datetime import datetime
from faker import Faker
import random

faker = Faker()

# Fetch all properties
response = client.table("properties").select("*").limit(1000).execute()
properties = response.data

# Group by owner_user_id
owners = defaultdict(list)
for prop in properties:
    owners[prop["owner_user_id"]].append(prop)

# %% [markdown]
# ✅ Step 2: Generate landlord profiles from grouped data

# %%
from dateutil.parser import parse as parse_datetime

def generate_landlord_profile(owner_id, owned_props):
    # Derive preferred locations
    preferred_locations = list({p["location"] for p in owned_props if p["location"]})

    # Parse datetime strings robustly
    created_times = [p["created_at"] for p in owned_props if p["created_at"]]
    created_times_dt = [parse_datetime(t) for t in created_times]
    joined_at = min(created_times_dt) if created_times_dt else datetime.utcnow()

    return {
        "user_id": owner_id,
        "full_name": faker.name(),
        "phone_number": faker.phone_number(),
        "verified": False,
        "bio": faker.text(max_nb_chars=100),
        "profile_image_url": None,
        "joined_at": joined_at.isoformat(),
        "preferred_locations": preferred_locations
    }


landlord_profiles = [
    generate_landlord_profile(owner_id, props)
    for owner_id, props in owners.items()
]

print(f"Generated {len(landlord_profiles)} landlord profiles.")
# Out:
# Generated 642 landlord profiles.

# %% [markdown]
# ✅ Step 3: Batch insert into landlord_profile table

# %%
from math import ceil

BATCH_SIZE = 50
num_batches = ceil(len(landlord_profiles) / BATCH_SIZE)

for i in range(num_batches):
    batch = landlord_profiles[i * BATCH_SIZE : (i + 1) * BATCH_SIZE]
    client.table("landlord_profile").insert(batch).execute()
    print(f"Inserted batch {i+1}/{num_batches} - {len(batch)} records.")
# Out:
# Inserted batch 1/13 - 50 records.
# Inserted batch 2/13 - 50 records.
# Inserted batch 3/13 - 50 records.
# Inserted batch 4/13 - 50 records.
# Inserted batch 5/13 - 50 records.
# Inserted batch 6/13 - 50 records.
# Inserted batch 7/13 - 50 records.
# Inserted batch 8/13 - 50 records.
# Inserted batch 9/13 - 50 records.
# Inserted batch 10/13 - 50 records.
# Inserted batch 11/13 - 50 records.
# Inserted batch 12/13 - 50 records.
# Inserted batch 13/13 - 42 records.

# %%
count_resp = client.table("landlord_profile").select("user_id", count="exact").execute()
print(f"Total landlord profiles in DB: {count_resp.count}")
# Out:
# Total landlord profiles in DB: 642

# %% [markdown]
# CLEAN EMAILS

# %%
from unidecode import unidecode
import re
from supabase import create_client
from src.api.config import settings

# Initialize Supabase client
client = create_client(settings.SUPABASE_URL, settings.SUPABASE_ANON_KEY)

# Cleaning function
def full_name_to_email(full_name: str) -> str:
    clean = unidecode(full_name)                  # Remove accents
    clean = clean.lower().strip()                 # Lowercase + strip
    clean = re.sub(r"\s+", ".", clean)            # Replace spaces with dots
    clean = re.sub(r"[^a-z0-9.]", "", clean)      # Remove special characters
    clean = re.sub(r"\.+", ".", clean).strip(".") # Remove repeated/trailing dots
    return f"{clean}@example.com"

# Fetch all landlords without email
response = client.table("landlord_profile").select("*").is_("email", None).execute()
landlords = response.data

# Update landlords with generated email
for landlord in landlords:
    full_name = landlord.get("full_name")
    if full_name:
        email = full_name_to_email(full_name)
        client.table("landlord_profile") \
            .update({"email": email}) \
            .eq("id", landlord["id"]) \
            .execute()

# %%
from unidecode import unidecode
import re
from supabase import create_client
from src.api.config import settings

# Initialize Supabase client
client = create_client(settings.SUPABASE_URL, settings.SUPABASE_ANON_KEY)

# Cleaning function
def full_name_to_email(full_name: str) -> str:
    clean = unidecode(full_name)                    # Remove accents
    clean = clean.lower().strip()                   # Lowercase + trim
    clean = re.sub(r"\s+", ".", clean)              # Replace whitespace with dots
    clean = re.sub(r"[^a-z0-9.]", "", clean)        # Remove non-alphanumerics
    clean = re.sub(r"\.+", ".", clean).strip(".")   # Collapse repeated dots and trim
    return f"{clean}@example.com"

# Fetch all landlords (no filtering)
response = client.table("landlord_profile").select("*").execute()
landlords = response.data

print(f"Found {len(landlords)} landlords. Updating emails...")

# Update all with cleaned email
for landlord in landlords:
    full_name = landlord.get("full_name", "")
    id = landlord["id"]

    if not full_name:
        print(f"Skipping landlord id={id}: missing full_name")
        continue

    email = full_name_to_email(full_name)
    print(f"[id={id}] {full_name} → {email}")

    # Perform update
    client.table("landlord_profile") \
        .update({"email": email}) \
        .eq("id", id) \
        .execute()

print("✅ All landlord emails updated and cleaned.")
# Out:
# Found 645 landlords. Updating emails...
# Skipping landlord id=643: missing full_name
# [id=459] Karen Dillon → karen.dillon@example.com
# [id=460] Thomas Foster → thomas.foster@example.com
# [id=461] Michael Ali → michael.ali@example.com
# [id=462] Cameron Walters → cameron.walters@example.com
# [id=463] Tracie Reynolds → tracie.reynolds@example.com
# [id=464] Jane Bush → jane.bush@example.com
# [id=465] Kayla Weiss → kayla.weiss@example.com
# [id=466] Dustin Garcia → dustin.garcia@example.com
# [id=467] Mark Smith → mark.smith@example.com
# [id=468] Thomas Holden → thomas.holden@example.com
# [id=469] Tyler Henderson → tyler.henderson@example.com
# [id=470] Marissa Bonilla → marissa.bonilla@example.com
# [id=471] Christopher Goodwin → christopher.goodwin@example.com
# [id=472] Rachael Craig → rachael.craig@example.com
# [id=473] Mark Oliver → mark.oliver@example.com
# [id=474] Paul Brown → paul.brown@example.com
# [id=475] Adam Miller → adam.miller@example.com
# [id=476] Dr. Damon Schmidt III → dr.damon.schmidt.iii@example.com
# [id=477] Andrea Moore → andrea.moore@example.com
# [id=478] Dr. Pamela Martinez DDS → dr.pamela.martinez.dds@example.com
# [id=479] Michael Wagner → michael.wagner@example.com
# [id=480] Christopher Jarvis → christopher.jarvis@example.com
# [id=631] David Kaiser → david.kaiser@example.com
# [id=481] Barry Klein → barry.klein@example.com
# [id=482] Sandra Forbes → sandra.forbes@example.com
# [id=483] Zachary Johnson → zachary.johnson@example.com
# [id=484] Jeremy Potts → jeremy.potts@example.com
# [id=485] Stacey Maldonado → stacey.maldonado@example.com
# [id=486] Omar Holden → omar.holden@example.com
# [id=487] Kari Ray → kari.ray@example.com
# [id=488] Jose Evans → jose.evans@example.com
# Skipping landlord id=644: missing full_name
# [id=489] Kelly Watkins → kelly.watkins@example.com
# [id=490] Kenneth Caldwell → kenneth.caldwell@example.com
# [id=491] Samuel Pacheco → samuel.pacheco@example.com
# [id=492] Madison Osborn DDS → madison.osborn.dds@example.com
# [id=493] Stephen Smith → stephen.smith@example.com
# [id=494] Cheryl Jones → cheryl.jones@example.com
# [id=495] Christine Myers → christine.myers@example.com
# [id=496] Kelli Wilson → kelli.wilson@example.com
# [id=497] Deborah Weaver → deborah.weaver@example.com
# [id=498] Debra Lewis → debra.lewis@example.com
# [id=499] Michael Stein → michael.stein@example.com
# [id=500] Tina Church → tina.church@example.com
# [id=501] Dr. Albert Cohen → dr.albert.cohen@example.com
# [id=502] Dana Carney → dana.carney@example.com
# [id=503] Amanda Scott → amanda.scott@example.com
# [id=504] Benjamin Matthews → benjamin.matthews@example.com
# [id=505] Ashley Rodriguez → ashley.rodriguez@example.com
# [id=506] Catherine Hoffman → catherine.hoffman@example.com
# [id=507] Amber Gardner → amber.gardner@example.com
# [id=508] Shawn Kirby → shawn.kirby@example.com
# [id=509] Gary Nguyen → gary.nguyen@example.com
# [id=510] Thomas Burns → thomas.burns@example.com
# [id=511] Frank Montgomery → frank.montgomery@example.com
# [id=512] Michelle Rivera → michelle.rivera@example.com
# [id=513] Bradley Kennedy → bradley.kennedy@example.com
# [id=514] Jacob Padilla → jacob.padilla@example.com
# [id=515] Eduardo Salas → eduardo.salas@example.com
# [id=516] Jessica Mills → jessica.mills@example.com
# [id=517] Lisa Stein → lisa.stein@example.com
# [id=518] Scott Macias → scott.macias@example.com
# [id=519] William Huffman → william.huffman@example.com
# [id=645] Valeria Hernández → valeria.hernandez@example.com
# [id=520] Patrick Hill → patrick.hill@example.com
# [id=521] Megan Washington → megan.washington@example.com
# [id=642] Jonathan Sanchez → jonathan.sanchez@example.com
# [id=387] Michelle Hawkins → michelle.hawkins@example.com
# [id=388] Thomas Weaver → thomas.weaver@example.com
# [id=389] Amy Rivers → amy.rivers@example.com
# [id=390] Denise Miller → denise.miller@example.com
# [id=391] Brett Miller MD → brett.miller.md@example.com
# [id=392] Monique Lara → monique.lara@example.com
# [id=393] Jeffrey Daniels → jeffrey.daniels@example.com
# [id=394] Nicholas Arnold → nicholas.arnold@example.com
# [id=395] David Rodriguez → david.rodriguez@example.com
# [id=396] Deborah Johnston → deborah.johnston@example.com
# [id=397] David Taylor → david.taylor@example.com
# [id=398] Cheryl Wilkinson → cheryl.wilkinson@example.com
# [id=399] Katie Greer → katie.greer@example.com
# [id=400] Alison Delgado → alison.delgado@example.com
# [id=401] Amy Holmes → amy.holmes@example.com
# [id=402] Kiara Bowen → kiara.bowen@example.com
# [id=403] Ralph Woods → ralph.woods@example.com
# [id=404] Tina Griffith → tina.griffith@example.com
# [id=405] Brandon Hawkins → brandon.hawkins@example.com
# [id=406] Aaron Hill → aaron.hill@example.com
# [id=407] Elizabeth York → elizabeth.york@example.com
# [id=408] Teresa Burnett → teresa.burnett@example.com
# [id=409] Jonathan Thompson → jonathan.thompson@example.com
# [id=410] Stephanie Barnes → stephanie.barnes@example.com
# [id=411] Vincent Henderson → vincent.henderson@example.com
# [id=412] Christina Martinez → christina.martinez@example.com
# [id=413] Joseph Carter → joseph.carter@example.com
# [id=414] Nicole Ramirez → nicole.ramirez@example.com
# [id=415] Heather Miller → heather.miller@example.com
# [id=416] Mario Espinoza → mario.espinoza@example.com
# [id=417] Jessica Curtis → jessica.curtis@example.com
# [id=418] Tiffany Guzman → tiffany.guzman@example.com
# [id=419] Jessica Acevedo → jessica.acevedo@example.com
# [id=420] Jillian Hernandez → jillian.hernandez@example.com
# [id=421] Justin Caldwell → justin.caldwell@example.com
# [id=422] Mr. Michael Mills DDS → mr.michael.mills.dds@example.com
# [id=423] Frank Adams → frank.adams@example.com
# [id=424] Brett Green → brett.green@example.com
# [id=425] Connor Mayer → connor.mayer@example.com
# [id=426] Joseph Vaughan → joseph.vaughan@example.com
# [id=427] Michael Dickerson → michael.dickerson@example.com
# [id=428] Jacob Wilson → jacob.wilson@example.com
# [id=429] Taylor Marshall → taylor.marshall@example.com
# [id=430] Lori West → lori.west@example.com
# [id=431] Christopher Fields → christopher.fields@example.com
# [id=432] Justin Nguyen → justin.nguyen@example.com
# [id=433] Jordan Hoffman → jordan.hoffman@example.com
# [id=434] Brittney Richardson → brittney.richardson@example.com
# [id=435] Jennifer Weiss → jennifer.weiss@example.com
# [id=436] Martin Vega → martin.vega@example.com
# [id=437] Paul Phillips → paul.phillips@example.com
# [id=438] Kevin Willis → kevin.willis@example.com
# [id=439] Kyle Barber → kyle.barber@example.com
# [id=440] Joshua Rose → joshua.rose@example.com
# [id=441] Thomas Robertson Jr. → thomas.robertson.jr@example.com
# [id=442] Robert Haley → robert.haley@example.com
# [id=443] Paul Morris → paul.morris@example.com
# [id=444] Jason Odom → jason.odom@example.com
# [id=445] Richard Williams → richard.williams@example.com
# [id=446] Michelle Cooke → michelle.cooke@example.com
# [id=447] Joseph Thompson → joseph.thompson@example.com
# [id=448] Cynthia Hill → cynthia.hill@example.com
# [id=449] Natalie Atkins → natalie.atkins@example.com
# [id=450] Colleen Robertson → colleen.robertson@example.com
# [id=451] Nicholas Gonzales → nicholas.gonzales@example.com
# [id=452] Kristina Villa → kristina.villa@example.com
# [id=453] Curtis Bauer → curtis.bauer@example.com
# [id=454] Colleen West → colleen.west@example.com
# [id=455] Michelle Newton → michelle.newton@example.com
# [id=456] Daniel Mccoy → daniel.mccoy@example.com
# [id=457] Wendy Jones → wendy.jones@example.com
# [id=458] Jason Hardy → jason.hardy@example.com
# [id=1] Patricia Christensen → patricia.christensen@example.com
# [id=2] Alexis Powell → alexis.powell@example.com
# [id=3] Peter Parker → peter.parker@example.com
# [id=4] Angela Walker → angela.walker@example.com
# [id=5] Theresa Hernandez → theresa.hernandez@example.com
# [id=6] Tammie Williams → tammie.williams@example.com
# [id=7] Kevin Mullins → kevin.mullins@example.com
# [id=8] Ashley Tapia → ashley.tapia@example.com
# [id=9] Jared Taylor → jared.taylor@example.com
# [id=551] Valerie Ross → valerie.ross@example.com
# [id=552] David Morrison → david.morrison@example.com
# [id=553] Anthony Smith → anthony.smith@example.com
# [id=554] Angelica Horton → angelica.horton@example.com
# [id=555] Corey Holmes → corey.holmes@example.com
# [id=556] Michael Freeman → michael.freeman@example.com
# [id=557] Curtis Bender → curtis.bender@example.com
# [id=558] Brett Brown DDS → brett.brown.dds@example.com
# [id=559] Nathaniel Murillo → nathaniel.murillo@example.com
# [id=560] Erin Goodwin → erin.goodwin@example.com
# [id=561] Joy Foster → joy.foster@example.com
# [id=562] Gary Estrada → gary.estrada@example.com
# [id=563] Mr. Gary Kidd → mr.gary.kidd@example.com
# [id=564] Dawn Church → dawn.church@example.com
# [id=565] John Rodriguez → john.rodriguez@example.com
# [id=566] Hannah Brooks → hannah.brooks@example.com
# [id=567] Kimberly Scott → kimberly.scott@example.com
# [id=568] Sarah Sexton → sarah.sexton@example.com
# [id=569] Megan Molina → megan.molina@example.com
# [id=570] John Mccullough → john.mccullough@example.com
# [id=571] Timothy Price → timothy.price@example.com
# [id=572] Samuel Ibarra IV → samuel.ibarra.iv@example.com
# [id=573] Mark Alexander → mark.alexander@example.com
# [id=574] Valerie Collins → valerie.collins@example.com
# [id=575] Kristi Carroll → kristi.carroll@example.com
# [id=576] Christopher Williams → christopher.williams@example.com
# [id=577] Sarah Floyd → sarah.floyd@example.com
# [id=578] Paul Ferguson → paul.ferguson@example.com
# [id=579] Katelyn Baldwin → katelyn.baldwin@example.com
# [id=580] Andrea Osborne → andrea.osborne@example.com
# [id=581] Kelly Baker → kelly.baker@example.com
# [id=582] Jose Woods → jose.woods@example.com
# [id=583] Jessica Escobar → jessica.escobar@example.com
# [id=584] Bethany Johnson → bethany.johnson@example.com
# [id=585] Kenneth Robertson → kenneth.robertson@example.com
# [id=586] Julie Palmer → julie.palmer@example.com
# [id=587] Craig Moore → craig.moore@example.com
# [id=588] Carolyn Martin → carolyn.martin@example.com
# [id=589] John Gallagher → john.gallagher@example.com
# [id=590] Amy Pollard → amy.pollard@example.com
# [id=591] Jerry Knox → jerry.knox@example.com
# [id=592] Olivia Hicks → olivia.hicks@example.com
# [id=632] Timothy Turner → timothy.turner@example.com
# [id=593] Thomas Powell → thomas.powell@example.com
# [id=594] Reginald Steele → reginald.steele@example.com
# [id=595] Catherine Burns → catherine.burns@example.com
# [id=596] Deborah Brown → deborah.brown@example.com
# [id=597] Samuel Clark → samuel.clark@example.com
# [id=598] Joshua Anderson → joshua.anderson@example.com
# [id=599] John Castaneda → john.castaneda@example.com
# [id=600] Michael Mann → michael.mann@example.com
# [id=601] Amy Acosta → amy.acosta@example.com
# [id=602] Cassandra Beasley → cassandra.beasley@example.com
# [id=603] Michael Lewis → michael.lewis@example.com
# [id=604] Audrey Morris → audrey.morris@example.com
# [id=605] Mary Allen → mary.allen@example.com
# [id=606] Katherine Robinson → katherine.robinson@example.com
# [id=607] Lawrence Moreno → lawrence.moreno@example.com
# [id=608] Emily Fletcher → emily.fletcher@example.com
# [id=609] Ms. Veronica Clark → ms.veronica.clark@example.com
# [id=610] Ashley Morales → ashley.morales@example.com
# [id=611] Kaitlyn Hatfield → kaitlyn.hatfield@example.com
# [id=612] Eric Singh → eric.singh@example.com
# [id=613] John Stone → john.stone@example.com
# [id=614] James Mccormick → james.mccormick@example.com
# [id=615] Hannah Sanchez → hannah.sanchez@example.com
# [id=616] Kathryn Anderson → kathryn.anderson@example.com
# [id=617] Christopher Foster → christopher.foster@example.com
# [id=618] Valerie Johnson → valerie.johnson@example.com
# [id=619] Stacy Olson → stacy.olson@example.com
# [id=620] Laurie Jackson → laurie.jackson@example.com
# [id=621] Kathy Beasley → kathy.beasley@example.com
# [id=622] Fernando Harris → fernando.harris@example.com
# [id=623] Sandra Castillo DDS → sandra.castillo.dds@example.com
# [id=624] Teresa Cox → teresa.cox@example.com
# [id=625] Kathryn Jordan → kathryn.jordan@example.com
# [id=626] Benjamin Barnes → benjamin.barnes@example.com
# [id=627] William Cuevas MD → william.cuevas.md@example.com
# [id=628] Anthony Henderson → anthony.henderson@example.com
# [id=629] Barbara Butler → barbara.butler@example.com
# [id=630] Angela Clark → angela.clark@example.com
# [id=633] Jessica Kirby → jessica.kirby@example.com
# [id=634] Colleen Smith → colleen.smith@example.com
# [id=635] Samuel Carey → samuel.carey@example.com
# [id=636] Steven Johnson → steven.johnson@example.com
# [id=637] Lance White → lance.white@example.com
# [id=638] Jennifer Grant → jennifer.grant@example.com
# [id=639] Amy Johnson → amy.johnson@example.com
# [id=640] James Gomez → james.gomez@example.com
# [id=641] Ronald Bishop → ronald.bishop@example.com
# ✅ All landlord emails updated and cleaned.
